# %%
import torch 

# create random tensor
x = torch.rand(10, 12, 5)

# %%
df
# Out:
#   metric_name  threshold  min_threshold  max_threshold  fold    TOTAL      TP  \
# 0   num_nodes        100              0           2000     0  31514.0  1085.0
# 1   num_nodes        100              0           2000     1  37095.0  1734.0
# 2   num_nodes        102              0           2000     2  62860.0  1645.0
# 3   num_nodes        103              0           2000     3  44591.0  1798.0
# 4   num_nodes        100              0           2000     4  28496.0  1012.0
#
#         FP      FN       TN  precision    recall        f1  balanced_accuracy  \
# 0  11193.0   492.0  18744.0   0.088369  0.688015  0.156622           0.657065
# 1  12262.0  1022.0  22077.0   0.123893  0.629173  0.207020           0.636043
# 2  18971.0  1254.0  40990.0   0.079792  0.567437  0.139911           0.625524
# 3  14827.0   793.0  27173.0   0.108150  0.693941  0.187136           0.670458
# 4  10268.0   444.0  16772.0   0.089716  0.695055  0.158920           0.657661
#
#    accuracy
# 0  0.629212
# ...

# %%
import pandas as pd 
# read thresholds/baseline.csv

df = pd.read_csv('thresholds/baseline.csv')
del df['metric_name']
#for each numerical row compute mean and std
df.std()
# Out:
# threshold                1.414214
# min_threshold            0.000000
# max_threshold            0.000000
# fold                     1.581139
# TOTAL                13714.031964
# TP                     375.745526
# FP                    3499.764235
# FN                     345.341860
# TN                    9691.093473
# precision                0.017793
# recall                   0.056002
# f1                       0.026792
# balanced_accuracy        0.018158
# accuracy                 0.021351
# dtype: float64

# %%
df.mean()
# Out:
# threshold              101.000000
# min_threshold            0.000000
# max_threshold         2000.000000
# fold                     2.000000
# TOTAL                40911.200000
# TP                    1454.800000
# FP                   13504.200000
# FN                     801.000000
# TN                   25151.200000
# precision                0.097984
# recall                   0.654724
# f1                       0.169922
# balanced_accuracy        0.649350
# accuracy                 0.644630
# dtype: float64
